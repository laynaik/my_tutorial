# %%
n_points=100

# %%
n_points
# Out:
# 100

# %%
import numpy as np

# %%
x=np.linspace(0,1,n_points)

# %%
x
# Out:
# array([0.        , 0.01010101, 0.02020202, 0.03030303, 0.04040404,
#        0.05050505, 0.06060606, 0.07070707, 0.08080808, 0.09090909,
#        0.1010101 , 0.11111111, 0.12121212, 0.13131313, 0.14141414,
#        0.15151515, 0.16161616, 0.17171717, 0.18181818, 0.19191919,
#        0.2020202 , 0.21212121, 0.22222222, 0.23232323, 0.24242424,
#        0.25252525, 0.26262626, 0.27272727, 0.28282828, 0.29292929,
#        0.3030303 , 0.31313131, 0.32323232, 0.33333333, 0.34343434,
#        0.35353535, 0.36363636, 0.37373737, 0.38383838, 0.39393939,
#        0.4040404 , 0.41414141, 0.42424242, 0.43434343, 0.44444444,
#        0.45454545, 0.46464646, 0.47474747, 0.48484848, 0.49494949,
#        0.50505051, 0.51515152, 0.52525253, 0.53535354, 0.54545455,
#        0.55555556, 0.56565657, 0.57575758, 0.58585859, 0.5959596 ,
#        0.60606061, 0.61616162, 0.62626263, 0.63636364, 0.64646465,
#        0.65656566, 0.66666667, 0.67676768, 0.68686869, 0.6969697 ,
#        0.70707071, 0.71717172, 0.72727273, 0.73737374, 0.74747475,
#        0.75757576, 0.76767677, 0.77777778, 0.78787879, 0.7979798 ,
#        0.80808081, 0.81818182, 0.82828283, 0.83838384, 0.84848485,
#        0.85858586, 0.86868687, 0.87878788, 0.88888889, 0.8989899 ,
#        0.90909091, 0.91919192, 0.92929293, 0.93939394, 0.94949495,
#        0.95959596, 0.96969697, 0.97979798, 0.98989899, 1.        ])

# %%
z=np.sin(2*np.pi*x)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,0))

# %%
plt.plot(x,z,'g-')

# %%
eta=.4*np.random.normal(0,1,n_points)

# %%
eta
# Out:
# array([-0.17890478, -0.01395253, -0.303908  ,  0.27169085, -0.48815027,
#        -0.33846176,  0.58589704,  0.13441221,  0.09084601,  0.11366298,
#        -0.14209777,  0.62595144,  0.45872317, -0.65686815, -0.38823968,
#        -0.15127395,  0.42698556,  0.58569198, -0.67403117, -0.30717355,
#         0.41105848,  0.50061947, -0.4387592 ,  0.00226996, -0.73750561,
#         0.27986471,  0.16272822,  0.04214535, -0.15434939,  0.44187754,
#         0.08851064, -0.05926289,  0.35839089, -0.21078923,  0.01770753,
#         0.13101878,  0.24933695, -0.17236666,  0.31897861, -0.10915017,
#        -0.02560737,  0.22663392, -0.37413511, -0.3494242 , -0.07235525,
#         0.2341237 , -0.6153988 ,  0.56836292,  0.01610389,  0.42709045,
#         0.30199489, -0.60824593, -0.21256475, -0.02952658, -0.14694644,
#         0.18089435,  0.23664501, -0.31151799,  0.18086895, -0.11526793,
#         0.20224345,  0.17992232, -0.4529381 ,  0.00152842,  0.01560666,
#        -0.58442435,  0.54832591,  0.77617591, -0.12223629,  0.95324264,
#        -0.10796649, -0.0101525 , -0.34554296, -0.23414945,  0.46664696,
#         0.66409528,  0.01078858,  0.07941304,  0.59472176,  0.35589283,
#         0.50913935,  0.03369921,  0.40119103, -0.28558203,  0.61888091,
#         0.79712536,  0.37849974,  0.07575904, -0.09356159,  0.52275199,
#         0.14562198,  0.23687693, -0.46293542, -0.82434621,  0.13940743,
#        -0.14014828,  0.96290108, -0.07427198, -0.32270561,  0.65135457])

# %%
plt.plot(x,eta,'r')

# %%
t=z+eta
plt.plot(x,z,'g',x,t,'bo')
plt.legend(('sine wave','noisy data'))

# %%
sample_points=10
import numpy as np
x_sample=np.linspace(0,1,sample_points)
eta_sample=.2*np.random.normal(0,1,sample_points)
t_sample=np.sin(2*np.pi*x_sample)+eta_sample
import matplotlib.pyplot as plt
plt.plot(x_sample,t_sample,'bo',x,z,'g-')
plt.legend(('noisy sample point','sine wave'))

# %% [markdown]
# # polynomial curve fitting

# %%
m=3
coeff=np.polyfit(x_sample,t_sample,m)
print(coeff)
# Out:
# [ 18.26089683 -27.75894751   9.54016     -0.09641809]

# %%
p=np.poly1d(coeff)
print(p)
# Out:
#        3         2
# 18.26 x - 27.76 x + 9.54 x - 0.09642

# %%
y_pred=p(x_sample)

# %%
plt.plot(x_sample,t_sample,'bo',x_sample,y_pred,'r-')
plt.legend(('training data','model with m=3'))

# %%
err=0.5*(np.sum(y_pred-t_sample)**2)
print(err)
# Out:
# 2.633988458791481e-27

# %%
n=5
x_new=np.linspace(0,1,n)
eta_new=.2*np.random.normal(0,1,n)
y_new=np.sin(2*np.pi*x_new)+eta_new

y_new=p(x_new)

plt.plot(x_sample,t_sample,'bo',x,z,'g',x_new,y_new,'ro')
plt.legend(('taining data','model','testing data'))

# %%
z3=np.polyfit(x_sample,t_sample,3)
p3=np.poly1d(z3)
y3=p3(x_sample)

z9=np.polyfit(x_sample,t_sample,9)
p9=np.poly1d(z9)
y9=p9(x_sample)

plt.plot(x_sample,t_sample,'bo',x_sample,y3,'g',x_sample,y9,'r')
plt.legend(('sample data','m=3','m=9'))
